# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
train_df = pd.read_csv("Final_Housing_Train_Data.csv")

# %%
test_df = pd.read_csv("Final_Housing_Test_Data.csv")

# %%
X_train = train_df.drop('SalePrice',axis=1)

# %%
y_train = train_df['SalePrice']

# %%
X_test = test_df

# %%
X_test.head()
# Out:
#      Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0  1461          20         80.0    11622            5            6
# 1  1462          20         81.0    14267            6            6
# 2  1463          60         74.0    13830            5            5
# 3  1464          60         78.0     9978            6            6
# 4  1465         120         43.0     5005            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_ConLI  \
# 0       1961          1961         0.0       468.0  ...               0
# 1       1958          1958       108.0       923.0  ...               0
# 2       1997          1998         0.0       791.0  ...               0
# 3       1998          1998        20.0       602.0  ...               0
# 4       1992          1992         0.0       263.0  ...               0
#
#    SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# 0               0             0             0            1
# ...

# %%
X_train.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_ConLI  SaleType_ConLw  \
# 0          2003       196.0       706.0  ...               0               0
# 1          1976         0.0       978.0  ...               0               0
# 2          2002       162.0       486.0  ...               0               0
# 3          1970         0.0       216.0  ...               0               0
# 4          2000       350.0       655.0  ...               0               0
#
# ...

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
# # Random Forest Model Predictions

# model = RandomForestRegressor(n_estimators=200)
# model.fit(X_train,y_train)
# y_predictions = model.predict(X_test)
# y_predictions

# %%
# GradientBoost Regression model prediction

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV

# %%
# gd_model = GradientBoostingRegressor()

# grid_param = {
#     'learning_rate':[0.1,0.05,0.2],
#     'n_estimators': [50,100,150,200],
#     'max_depth':[3,4,5,6],
# }

# grid_model = GridSearchCV(estimator=gd_model,param_grid=grid_param)
# grid_model.fit(X_train,y_train)

# %%
# y_predictions = grid_model.predict(X_test)

# %%
# XGB Regressor model prediction

# %%
from xgboost import XGBRegressor

# %%
xg_model = XGBRegressor(n_estimators=200,learning_rate=0.1,max_depth=6)

# %%
param_grid = {
    'n_estimators':[50,100,200,300,400,500],
    'learning_rate':[0.1,0.05,0.2],
    'max_depth':[3,4,5,6],
    'booster':['gbtree','gblinear','dart'],
}

# %%
# xg_grid_model = GridSearchCV(estimator=xg_model,param_grid=param_grid,cv=5)

# %%
xg_model.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.1, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=200, n_jobs=8, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
y_predictions = xg_model.predict(X_test)

# %%
# mean_absolute_error(y_test,y_predictions)

# %%
prediction = pd.DataFrame(y_predictions,columns=['SalePrice'])
sample_df = pd.read_csv('sample_submission.csv')
final_predictions = pd.concat([sample_df['Id'],prediction],axis=1)

final_predictions.to_csv("Final_Submition1.csv",index=False)

# %%
final_predictions
# Out:
#         Id      SalePrice
# 0     1461  125127.921875
# 1     1462  154777.718750
# 2     1463  176080.968750
# 3     1464  191388.046875
# 4     1465  194967.468750
# ...    ...            ...
# 1454  2915   79889.351562
# 1455  2916   83464.898438
# 1456  2917  152433.906250
# 1457  2918  106871.757812
# 1458  2919  223012.593750
#
# [1459 rows x 2 columns]
# ERROR:asyncio:Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\vishal\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\vishal\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# ERROR:asyncio:Exception in callback BaseSelectorEventLoop._read_from_self()
# ...
